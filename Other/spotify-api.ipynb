# %%
# you should only have to run this once and you'll be good to go

# !pip install spotipy
#!pip install lyricsgenius

# %%
# import block

import sys
from time import time
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import numpy as np
import csv
from sklearn.cluster import KMeans
from scipy.spatial import distance
#import lyricsgenius

# %%
# ------------------------- SPOTIFY API HOOKIN
#scope = 'user-library-read'
scope = 'user-library-read'

# ------------------------- SPOTIFY API HOOKIN

sp = spotipy.Spotify(
        auth_manager=spotipy.SpotifyOAuth(
          client_id='f2690140b6d049a3a7aa4a0f6d4be012',
          client_secret='b3ddd5dd34db4f37a509d0313ba0c2fa',
          redirect_uri='http://localhost/',    
          scope=scope, open_browser=False))

# %%
#Pick an album
album_results = sp.album('https://open.spotify.com/album/42UPwzHW8rhA13t5JJxp09?si=MRcruXJXS2SqKJvIBwGDyA')
print(album_results['artists'][0]['name'])

#Say we just want the album track info
#album_track_results = sp.album_tracks('https://open.spotify.com/album/2uEcfaomYrfuwGz4ikMU8a?si=y_svHkkcTgWolEEQEQz17g')

#Now, an artist
artist = sp.artist('https://open.spotify.com/artist/6FlOCziOXI157pvUREAh3E?si=npnZvZVbQSeKJM15AKbdyA')
#print(artist)

#An artist's albums
#artist_albums = sp.artist_albums('https://open.spotify.com/artist/6FlOCziOXI157pvUREAh3E?si=npnZvZVbQSeKJM15AKbdyA')

#Artist's top tracks
#top_tracks = sp.artist_top_tracks('https://open.spotify.com/artist/6FlOCziOXI157pvUREAh3E?si=npnZvZVbQSeKJM15AKbdyA', country='US')
#print(top_tracks)

#Playlist
#playlist = sp.playlist('https://open.spotify.com/playlist/5zTUX59PIGj24TuLWBxnQC?si=377fee678cf84dd3')
#print(playlist['images'])

#Track
#track = sp.track('https://open.spotify.com/track/3MfLyIdGHwhoygfd1wtZnH?si=b01105a51a5b43d2')
#print(track)

#Audio features
#audio_features = sp.audio_features('https://open.spotify.com/track/3MfLyIdGHwhoygfd1wtZnH?si=b01105a51a5b43d2')
#print(audio_features)
